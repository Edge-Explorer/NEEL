# %% [markdown]
# # Notebook 05: ML Models
#
# Purpose:
# - Train interpretable ML models on engineered features
# - Generate predictive signals (not final answers)
# - Save trained models for backend inference

# %%
import pandas as pd
import numpy as np 

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.cluster import KMeans
from sklearn.metrics import mean_squared_error, accuracy_score
import joblib

# %%
time_df = pd.read_csv("../data/processed/time_features.csv")
study_df = pd.read_csv("../data/processed/study_features.csv")
habit_df = pd.read_csv("../data/processed/habit_features.csv")

# %% [markdown]
# ### MODEL 1 — PRODUCTIVITY REGRESSION

# %%
X_time=time_df[
    ["work_ratio", "leisure_ratio", "health_ratio", "routine_variability"]
]
y_time=time_df["productivity_score"]

# %%
X_train, X_test, y_train, y_test=train_test_split(
    X_time, y_time, test_size=0.2, random_state=42
)

# %%
prod_model=LinearRegression()
prod_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred=prod_model.predict(X_test)
mean_squared_error(y_test, y_pred)
# Out:
# 130.92628020904013

# %%
joblib.dump(prod_model, "../models/productivity_model.pkl")
# Out:
# ['../models/productivity_model.pkl']

# %% [markdown]
# ### MODEL 2 — ACADEMIC PERFORMANCE MODEL

# %%
X_study = study_df[
    ["study_minutes_per_week", "attendance_percentage", "assignments_completed"]
]
y_study = study_df["exam_score"]

# %%
X_train, X_test, y_train, y_test=train_test_split(
    X_study, y_study, test_size=0.2, random_state=42
)

# %%
study_model = LinearRegression()
study_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
joblib.dump(study_model, "../models/study_performance_model.pkl")
# Out:
# ['../models/study_performance_model.pkl']

# %% [markdown]
# ### MODEL 3 — HABIT RISK CLASSIFIER

# %%
habit_df["risk_label"] = np.where(
    habit_df["stress_level"] > habit_df["motivation_level"],
    1,
    0
)

# %%
X_habit = habit_df[
    ["distraction_load", "recovery_score", "time_management_score"]
]
y_habit = habit_df["risk_label"]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_habit, y_habit, test_size=0.2, random_state=42
)

# %%
habit_model = LogisticRegression()
habit_model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
joblib.dump(habit_model, "../models/habit_risk_model.pkl")
# Out:
# ['../models/habit_risk_model.pkl']

# %% [markdown]
# ### MODEL 4 — BEHAVIOR CLUSTERING

# %%
X_cluster = time_df[
    ["work_minutes", "leisure_minutes", "exercise_minutes", "sleep_minutes"]
]

# %%
kmeans=KMeans(n_clusters=3, random_state=42)
kmeans.fit(X_cluster)
# Out:
# KMeans(n_clusters=3, random_state=42)

# %%
joblib.dump(kmeans, "../models/routine_cluster_model.pkl")
# Out:
# ['../models/routine_cluster_model.pkl']

# %% [markdown]
# ## ML Model Summary
#
# - Trained interpretable ML models
# - Focused on behavioral signals, not accuracy
# - Saved models for backend inference
# - ML outputs will be validated by supervisor and explained by LLM
